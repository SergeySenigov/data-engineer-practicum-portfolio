# %%
import os, sys
os.environ['HADOOP_CONF_DIR'] = '/etc/hadoop/conf'
os.environ['YARN_CONF_DIR'] = '/etc/hadoop/conf'
 
import findspark
findspark.init()
findspark.find()
 
import pyspark.sql.functions as F
from pyspark.sql import SparkSession, DataFrame
from pyspark.context import SparkContext, SparkConf
from pyspark.sql.window import Window
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, LongType, BooleanType, IntegerType
from pyspark.storagelevel import StorageLevel

import pr7_classes as pr7

# %%
spark = pr7.get_session_notebook()
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/usr/lib/spark/jars/slf4j-log4j12-1.7.30.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/lib/hadoop/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2023-04-25 08:49:09,074 WARN util.Utils: Your hostname, fhmev7mr8ojds7g6cgdj resolves to a loopback address: 127.0.1.1; using 172.16.0.23 instead (on interface eth0)
# 2023-04-25 08:49:09,075 WARN util.Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2023-04-25 08:49:31,839 WARN cluster.YarnSchedulerBackend$YarnSchedulerEndpoint: Attempted to request executors before the AM has registered!

# %%
pr7.print_conf(spark)
print("app_id".ljust(44), spark.sparkContext._jsc.sc().applicationId())
# Out:
# app_id                                       application_1674128476788_24982

# %%
def main(spark, dfname):
    if dfname == 'Cities':
        citiesRaw = pr7.CitiesRaw(spark)
        citiesRaw.calc(True)
        citiesRaw.desc()

        cities = pr7.Cities(spark, citiesRaw)
        cities.calc(True)
        cities.desc()
        return 
    
    if dfname == 'EventsWithCitiesAll':
        eventsSource = pr7.EventsSource(spark)
        eventsSource.read('2022-03-01')
        eventsSource.desc()

        eventsRaw = pr7.EventsRaw(spark, eventsSource)
        eventsRaw.calc(True)
        eventsRaw.desc()

        eventsWithUserAndCoords = pr7.EventsWithUserAndCoords(spark, eventsRaw) 
        eventsWithUserAndCoords.calc(True)
        eventsWithUserAndCoords.desc()

        cities = pr7.Cities(spark, None)
        cities.read()
        cities.desc()

        eventsWithCitiesPartial = pr7.EventsWithCitiesPartial(spark, eventsWithUserAndCoords, cities) 
        eventsWithCitiesPartial.calc(True)
        eventsWithCitiesPartial.desc()

        eventsWithCitiesAll = pr7.EventsWithCitiesAll(spark, eventsWithCitiesPartial) 
        eventsWithCitiesAll.calc(True)
        eventsWithCitiesAll.desc()
        return     

    if dfname == 'Report4':
        eventsWithUserAndCoords = pr7.EventsWithUserAndCoords(spark, None)
        eventsWithUserAndCoords.read()
        eventsWithUserAndCoords.desc()

        userChannelSubscriptions = pr7.UserChannelSubscriptions(spark, eventsWithUserAndCoords)
        userChannelSubscriptions.calc(True, 0.1)
        userChannelSubscriptions.desc()

        userCommonChannels = pr7.UserCommonChannels(spark, userChannelSubscriptions, userChannelSubscriptions)
        userCommonChannels.calc(True)
        userCommonChannels.desc()

        usersCorresponded = pr7.UsersCorresponded(spark, eventsWithUserAndCoords)
        usersCorresponded.calc(True)
        usersCorresponded.desc()

        eventsWithCitiesAll = pr7.EventsWithCitiesAll(spark, None)
        eventsWithCitiesAll.read()
        eventsWithCitiesAll.desc()

        usersLeft = pr7.Users(spark, eventsWithCitiesAll)
        usersLeft.read()

        usersRight = pr7.Users(spark, eventsWithCitiesAll)
        usersRight.read()

        usersNear = pr7.UsersNear(spark, usersLeft, usersRight)
        usersNear.calc(True)
        usersNear.desc()

        report4 = pr7.Report4(spark, userCommonChannels, usersCorresponded, usersNear)
        report4.calc(True)

# %%
eventsSource = pr7.EventsSource(spark)
eventsSource.read('2022-04-01')
eventsSource.desc()
# Out:
# 2023-04-25 08:51:37,244 WARN datasources.SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# [Stage 3:>                                                          (0 + 1) / 1]
# Count: 9958321 Layer: -source Name: events
# RDD Name: events
# Partitons cnt: 932
# root
#  |-- event_type: string (nullable = true)
#  |-- message_from: long (nullable = true)
#  |-- message_to: long (nullable = true)
#  |-- reaction_from: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- subscription_channel: long (nullable = true)
#  |-- date: date (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- message_id: long (nullable = true)
#  |-- datetime: string (nullable = true)

# %%
eventsRaw = pr7.EventsRaw(spark, eventsSource)
eventsRaw.calc()
eventsRaw.desc()

eventsWithCitiesPartial = pr7.EventsWithCitiesPartial(spark, eventsWithUserAndCoords, cities) #events_full_coords
eventsWithCitiesAll = pr7.EventsWithCitiesAll(spark, eventsWithCitiesPartial)
registrationsWithCities = pr7.RegistrationsWithCities(spark, eventsWithCitiesAll)
eventsWithRegsWithCities = pr7.EventsWithRegsWithCities(spark, eventsWithCitiesAll, registrationsWithCities)

userTravelCities = pr7.UserTravelCities(spark, eventsWithCitiesAll)
userTravels = pr7.UserTravels(spark, userTravelCities)
report3 = pr7.Report3(spark, eventsWithRegsWithCities)
report2 = pr7.Report2(spark, users, userTravels)
# Out:
# 2023-04-25 09:19:25,729 WARN execution.CacheManager: Asked to cache already cached data.
# 2023-04-25 09:19:26,564 WARN scheduler.TaskSetManager: Stage 4 contains a task of very large size (5876 KiB). The maximum recommended task size is 1000 KiB.
# 2023-04-25 09:28:04,529 WARN scheduler.TaskSetManager: Stage 5 contains a task of very large size (5876 KiB). The maximum recommended task size is 1000 KiB.
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_929 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_842 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_745 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_11 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_50 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_209 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_614 !
# 2023-04-25 09:29:22,665 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_291 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_690 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_894 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_283 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_467 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_846 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_14 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_604 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_803 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_470 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_741 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_602 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_838 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_875 !
# 2023-04-25 09:29:22,666 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_286 !
# 2023-04-25 09:29:22,668 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_907 !
# 2023-04-25 09:29:22,668 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_554 !
# 2023-04-25 09:29:22,668 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_831 !
# 2023-04-25 09:29:22,668 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_857 !
# 2023-04-25 09:29:22,668 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_759 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_256 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_494 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_523 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_152 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_869 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_586 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_30 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_631 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_806 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_135 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_219 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_393 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_716 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_16 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_789 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_827 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_81 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_863 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_832 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_917 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_581 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_887 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_369 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_385 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_288 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_341 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_688 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_42 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_292 !
# 2023-04-25 09:29:22,669 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_778 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_9 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_424 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_509 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_867 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_187 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_8 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_239 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_758 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_532 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_27 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_580 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_108 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_743 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_920 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_129 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_649 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_679 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_873 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_74 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_695 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_107 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_358 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_175 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_138 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_845 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_927 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_563 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_105 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_170 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_363 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_270 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_441 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_294 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_476 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_111 !
# 2023-04-25 09:29:22,670 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_548 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_747 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_210 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_100 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_63 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_816 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_79 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_477 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_900 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_425 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_571 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_150 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_273 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_628 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_190 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_113 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_853 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_663 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_847 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_799 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_590 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_329 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_478 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_610 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_808 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_161 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_780 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_381 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_504 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_685 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_860 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_601 !
# 2023-04-25 09:29:22,671 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_637 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_822 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_622 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_164 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_241 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_928 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_179 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_882 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_343 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_336 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_922 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_34 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_88 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_567 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_423 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_141 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_752 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_38 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_370 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_916 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_188 !
# 2023-04-25 09:29:22,672 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_735 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_290 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_796 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_774 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_453 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_19 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_222 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_794 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_521 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_813 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_230 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_910 !
# 2023-04-25 09:29:22,673 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_706 !
# 2023-04-25 09:29:22,674 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_701 !
# 2023-04-25 09:29:22,674 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_171 !
# 2023-04-25 09:29:22,674 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_840 !
# 2023-04-25 09:29:22,674 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_757 !
# 2023-04-25 09:29:22,674 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_697 !
# 2023-04-25 09:29:22,674 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_908 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_351 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_257 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_833 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_271 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_726 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_712 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_429 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_666 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_115 !
# 2023-04-25 09:29:22,675 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_287 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_889 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_400 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_337 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_591 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_912 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_501 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_872 !
# 2023-04-25 09:29:22,676 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_248 !
# 2023-04-25 09:29:26,414 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_876 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_347 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_775 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_48 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_823 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_878 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_402 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_491 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_132 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_246 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_725 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_221 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_475 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_802 !
# 2023-04-25 09:29:26,415 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_54 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_98 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_127 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_307 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_710 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_526 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_667 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_668 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_538 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_454 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_527 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_619 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_145 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_116 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_181 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_103 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_482 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_648 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_185 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_440 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_545 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_180 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_200 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_29 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_662 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_578 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_40 !
# 2023-04-25 09:29:26,416 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_820 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_898 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_10 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_864 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_458 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_348 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_540 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_835 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_318 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_551 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_570 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_197 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_64 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_449 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_156 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_471 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_419 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_731 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_252 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_513 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_652 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_792 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_474 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_184 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_613 !
# 2023-04-25 09:29:26,417 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_618 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_211 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_579 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_675 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_442 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_235 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_805 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_350 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_825 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_592 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_372 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_39 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_714 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_361 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_421 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_68 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_899 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_122 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_512 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_319 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_529 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_528 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_166 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_740 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_272 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_766 !
# 2023-04-25 09:29:26,418 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_32 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_1 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_263 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_33 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_817 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_926 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_202 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_596 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_616 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_715 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_420 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_896 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_460 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_510 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_518 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_73 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_490 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_70 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_199 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_5 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_487 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_196 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_600 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_891 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_589 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_309 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_7 !
# 2023-04-25 09:29:26,419 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_865 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_582 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_160 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_390 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_225 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_492 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_120 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_203 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_139 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_177 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_689 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_705 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_322 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_858 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_682 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_183 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_514 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_656 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_718 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_435 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_299 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_395 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_493 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_259 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_353 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_763 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_605 !
# 2023-04-25 09:29:26,420 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_681 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_856 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_670 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_448 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_660 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_324 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_368 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_102 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_788 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_334 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_730 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_572 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_511 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_561 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_112 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_77 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_282 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_332 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_519 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_44 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_615 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_163 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_713 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_439 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_704 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_432 !
# 2023-04-25 09:29:26,421 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_930 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_193 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_330 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_555 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_680 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_828 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_645 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_479 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_834 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_728 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_62 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_198 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_866 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_389 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_879 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_383 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_574 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_346 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_461 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_269 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_433 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_768 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_41 !
# 2023-04-25 09:29:26,422 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_59 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_576 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_703 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_414 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_862 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_323 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_56 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_409 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_502 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_485 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_606 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_826 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_134 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_762 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_905 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_25 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_553 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_795 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_35 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_335 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_339 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_61 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_520 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_693 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_658 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_633 !
# 2023-04-25 09:29:26,423 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_312 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_411 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_399 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_809 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_367 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_742 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_797 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_226 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_267 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_207 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_340 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_437 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_672 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_691 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_678 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_724 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_654 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_90 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_195 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_43 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_104 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_430 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_153 !
# 2023-04-25 09:29:26,424 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_204 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_531 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_274 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_843 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_133 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_326 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_357 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_764 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_281 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_612 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_657 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_249 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_125 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_881 !
# 2023-04-25 09:29:26,425 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_345 !
# ...
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_408 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_167 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_376 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_394 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_868 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_12 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_530 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_162 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_711 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_818 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_243 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_687 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_886 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_646 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_850 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_880 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_609 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_921 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_480 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_295 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_465 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_859 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_83 !
# 2023-04-25 09:29:26,702 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_694 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_218 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_52 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_18 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_626 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_380 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_564 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_69 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_636 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_506 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_924 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_53 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_729 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_784 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_22 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_807 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_217 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_801 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_565 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_634 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_772 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_644 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_829 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_885 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_117 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_702 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_709 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_366 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_66 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_583 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_849 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_906 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_6 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_925 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_893 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_94 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_55 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_468 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_119 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_401 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_779 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_525 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_897 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_603 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_854 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_739 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_95 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_901 !
# 2023-04-25 09:29:26,703 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_300 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_771 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_101 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_848 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_21 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_136 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_815 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_599 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_671 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_277 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_250 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_785 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_537 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_427 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_143 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_798 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_569 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_173 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_489 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_717 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_431 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_824 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_216 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_914 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_918 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_673 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_349 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_382 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_923 !
# 2023-04-25 09:29:26,704 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_819 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_86 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_280 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_620 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_342 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_503 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_841 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_588 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_793 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_333 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_911 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_144 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_126 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_234 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_746 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_632 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_783 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_870 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_344 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_189 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_4 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_407 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_902 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_137 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_573 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_146 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_428 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_744 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_669 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_566 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_776 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_804 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_549 !
# 2023-04-25 09:29:26,705 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_871 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_303 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_258 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_837 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_338 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_176 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_451 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_686 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_750 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_268 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_760 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_110 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_397 !
# 2023-04-25 09:29:26,706 WARN storage.BlockManagerMasterEndpoint: No more replicas available for rdd_8_87 !
# [Stage 5:>                                                          (0 + 1) / 1]

# %%
# проверка
eventsWithRegsWithCities.df.groupBy('event_type').count().show()

# %%
eventsRaw = pr7.EventsRaw(spark, None)
eventsRaw.read('2022-08-01')
eventsRaw.desc()

# %%
eventsWithUserAndCoords = pr7.EventsWithUserAndCoords(spark, eventsRaw)
eventsWithUserAndCoords.calc(True)
eventsWithUserAndCoords.desc()

# %%
userChannelSubscriptions = pr7.UserChannelSubscriptions(spark, eventsWithUserAndCoords)
userChannelSubscriptions.read()
# сохранить для тестирования в userChannelSubscriptions только sample 10% 
userChannelSubscriptions.calc(True, 0.1)
userChannelSubscriptions.desc()

# %%
userChannelSubscriptions.df = userChannelSubscriptions.df.repartition(600)
userChannelSubscriptions.df = userChannelSubscriptions.df.cache()
userChannelSubscriptions.df.count()

# %%
userCommonChannels = pr7.UserCommonChannels(spark, userChannelSubscriptions, userChannelSubscriptions)
userCommonChannels = pr7.UserCommonChannels(spark, None, None)
userCommonChannels.read()
userCommonChannels.calc()
userCommonChannels.desc()

# %%
eventsWithUserAndCoords = pr7.EventsWithUserAndCoords(spark, None) 
eventsWithUserAndCoords.read()
eventsWithUserAndCoords.desc()

# %%
usersCorresponded = pr7.UsersCorresponded(spark, eventsWithUserAndCoords)
usersCorresponded = pr7.UsersCorresponded(spark, None)
usersCorresponded.df = usersCorresponded.eventsWithUserAndCoords.df.where(" event_type = 'message' and message_to is not null ")

usersCorresponded.df = usersCorresponded.df.withColumnRenamed('user_id', 'user_left')\
                         .withColumn('user_right', F.col('message_to').cast(StringType()))\
                         .select('user_left', 'user_right').distinct()

usersCorresponded.df = usersCorresponded.df.withColumn('temp_left', F.col('user_left'))
usersCorresponded.df = usersCorresponded.df.withColumn('user_left', F.when(F.col('user_left')>F.col('user_right'), F.col('user_right')).otherwise(F.col('user_left')))
usersCorresponded.df = usersCorresponded.df.withColumn('user_right', F.when(F.col('temp_left')>F.col('user_right'), F.col('temp_left')).otherwise(F.col('user_right')))
usersCorresponded.df = usersCorresponded.df.drop('temp_left')
usersCorresponded.df = usersCorresponded.df.select('user_left', 'user_right').distinct()
        
usersCorresponded.read()
usersCorresponded.calc()
usersCorresponded.desc()

# %%
usersLeft = pr7.Users(spark, None)
usersLeft.read()
usersLeft.desc()

# %%
usersRight = pr7.Users(spark, None)
usersRight.read()
usersRight.desc()

# %%
usersNear = pr7.UsersNear(spark, usersLeft, usersRight)
usersNear = pr7.UsersNear(spark, None, None)
usersNear.read()
usersNear.calc(True)
usersNear.desc()

# %%
usersNear.df.show(40)

# %%
report4 = pr7.Report4(spark, userCommonChannels, usersCorresponded, usersNear)
report4.calc(True)
report4.desc()
report4.df = usersNear.df.selectExpr('user_left', 'user_right', 'city_left', 'city_id_left as zone_id')
userCommonChannels.df = userCommonChannels.df.withColumnRenamed('user_left', 'ucc_user_left')
userCommonChannels.df = userCommonChannels.df.withColumnRenamed('user_right', 'ucc_user_right')

report4.df = report4.df.join(userCommonChannels.df, \
                    [report4.df.user_left == userCommonChannels.df.ucc_user_left, 
                     report4.df.user_right == userCommonChannels.df.ucc_user_right], 'inner')

report4.df = report4.df.join(usersCorresponded.df, \
                    [report4.df.user_left == usersCorresponded.df.user_left, 
                     report4.df.user_right == usersCorresponded.df.user_right], 'leftanti')
    
report4.df = report4.df.drop('city_left', 'subscription_channel', 'ucc_user_left', 'ucc_user_right')
report4.df.printSchema()

report4.df = report4.df.cache() ##!! cache
                
pr7.Saver.save(report4.df, report4.layer, report4.path)

# %%
report4.df = usersNear.df.select('user_left', 'user_right', 'city_left', 'city_id_left')
report4.df = report4.df.join(usersCorresponded.df, \
                    [report4.df.user_left == usersCorresponded.df.uc_user_left, 
                     report4.df.user_right == usersCorresponded.df.uc_user_right], 'left')
report4.df = report4.df.withColumn('processed_dttm', F.current_timestamp())
report4.df = report4.df.withColumn('local_time', \
                    F.when( (F.col('city_left') == 'Sydney') | (F.col('city_left') == 'Melbourne') | \
                            (F.col('city_left') == 'Brisbane') | (F.col('city_left') == 'Perth') | \
                            (F.col('city_left') == 'Adelaide') | (F.col('city_left') == 'Canberra') | \
                            (F.col('city_left') == 'Hobart') | (F.col('city_left') == 'Darwin')  \
                    , F.from_utc_timestamp(F.col('processed_dttm'), F.concat(F.lit('Australia/'), F.col('city_left'))))\
                     .otherwise(None))

report4.df = report4.df.where("uc_user_left is null")
report4.df = report4.df.drop('uc_user_left', 'uc_user_right', 'city_left')
report4.df = report4.df.withColumnRenamed('city_id_left', 'zone_id')

report4.df = report4.df.cache()

count= report4.df.count()

report4.read()
report4.df.show(200)
